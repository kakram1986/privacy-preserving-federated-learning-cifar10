# %% [markdown]
# """
# COM748 MSc Research Project
# -----------------------------------------
# Project:
# Privacy-Preserving Machine Learning Techniques
# for Secure Federated Learning Systems
#
# Researcher:
# Khawar Akram
#
# Dataset:
# CIFAR-10
#
# Notebook:
# 02_CIFAR10_Exploration
# """

# %%
import torch
import torchvision

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from torchvision import datasets
from torchvision import transforms

# %%
from torchvision import datasets

train_dataset = datasets.CIFAR10(
    root="/content/drive/MyDrive/COM748_Project/01_Dataset",
    train=True,
    download=True
)

test_dataset = datasets.CIFAR10(
    root="/content/drive/MyDrive/COM748_Project/01_Dataset",
    train=False,
    download=True
)
