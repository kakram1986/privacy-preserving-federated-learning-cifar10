# %% [markdown]
# # ==========================================================
# # COM748 MSc Project
# # Federated Learning using FedAvg
# #
# # Experiment:
# # F1 - Baseline Federated Learning (FedAvg)
# # ==========================================================

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

print(os.path.exists("/content/drive/MyDrive/COM748_Project"))
# Out:
# True

# %%
import os

PROJECT_ROOT = "/content/drive/MyDrive/COM748_Project"

for item in os.listdir(PROJECT_ROOT):
    print(item)
# Out:
# 01_Dataset
# 02_Notebooks
# 03_Source_Code
# 04_Models
# 05_Checkpoints
# 06_Results
# 07_Dissertation
# 08_Literature
# 09_Backups

# %%
# ==========================================================
# PROJECT IMPORTS
# ==========================================================

import os
import sys
import importlib

SOURCE_PATH = "/content/drive/MyDrive/COM748_Project/03_Source_Code"

if SOURCE_PATH not in sys.path:
    sys.path.append(SOURCE_PATH)

import config
import dataset
import model
import training
import evaluation
import aggregation
import experiment
import visualization
import aggregation
import client
import federated
import analysis


importlib.reload(client)
importlib.reload(federated)
importlib.reload(config)
importlib.reload(dataset)
importlib.reload(model)
importlib.reload(training)
importlib.reload(evaluation)
importlib.reload(aggregation)
importlib.reload(experiment)
importlib.reload(visualization)
importlib.reload(analysis)

print("✅ Modules Loaded Successfully")
# Out:
# ✅ Modules Loaded Successfully

# %%
import config

config.set_seed()

print("Random seed:", config.SEED)
# Out:
# Random seed: 42

# %%
print(config.DEVICE)

print(model.get_model())

print(dataset.get_dataloaders)

print(aggregation.fedavg)
# Out:
# cuda
# BaselineCNN(
#   (features): Sequential(
#     (0): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#     )
#     (1): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#     )
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
# ...

# %%
import sys

SOURCE_PATH = "/content/drive/MyDrive/COM748_Project/03_Source_Code"

if SOURCE_PATH not in sys.path:
    sys.path.insert(0, SOURCE_PATH)

print(SOURCE_PATH in sys.path)
# Out:
# True

# %%
# ==========================================================
# FEDERATED EXPERIMENT CONFIGURATION
# ==========================================================

EXPERIMENT = {

    # ------------------------------------------------------
    # Experiment Information
    # ------------------------------------------------------

    "id": "F-0",

    "version": "v1.0",

    "title": "FedAvg Baseline",

    "description": "Federated Learning Baseline",

    "algorithm": "FedAvg",

    # ------------------------------------------------------
    # Dataset
    # ------------------------------------------------------

    "dataset": "CIFAR-10",

    # ------------------------------------------------------
    # Federated Learning
    # ------------------------------------------------------

    "clients": config.NUM_CLIENTS,

    "rounds": config.ROUNDS,

    "local_epochs": config.LOCAL_EPOCHS,

    "learning_rate": config.CLIENT_LEARNING_RATE,

    "weight_decay": config.CLIENT_WEIGHT_DECAY,

    # ------------------------------------------------------
    # Differential Privacy
    # ------------------------------------------------------

    "enable_dp": config.ENABLE_DP,

    "max_grad_norm": config.MAX_GRAD_NORM,

    "noise_multiplier": config.NOISE_MULTIPLIER,

    # ------------------------------------------------------
    # Notes
    # ------------------------------------------------------

    "notes": "First Federated Learning Baseline Experiment"
}

print("✅ Federated experiment configuration loaded.")
# Out:
# ✅ Federated experiment configuration loaded.

# %%
fl = federated.FederatedLearning()

fl.create_clients()

print("Clients:", len(fl.clients))
# Out:
# ✅ 5 clients created.
# Clients: 5

# %%
import server

print(server.FederatedServer)
# Out:
# <class 'server.FederatedServer'>

# %%
srv = server.FederatedServer(config.DEVICE)

print(srv.get_model())
# Out:
# BaselineCNN(
#   (features): Sequential(
#     (0): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#     )
#     (1): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#     )
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): ConvBlock(
#       (block): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
# ...

# %%
weights = srv.get_weights()

print(type(weights))
print(len(weights))
# Out:
# <class 'collections.OrderedDict'>
# 42

# %%
weights = srv.get_weights()

srv.set_weights(weights)

print("✅ Global weights loaded successfully.")
# Out:
# ✅ Global weights loaded successfully.

# %%
history, best_accuracy, predictions, targets = fl.train()
# Out:
# ...
# FEDERATED LEARNING
# ...
#
# Communication Round 1/30
# [Round 01/30] Train=1.7226 | Test=2.6074 | Acc=9.77%
# ★ New Best Accuracy: 9.77% (Round 1)
#
# Communication Round 2/30
# [Round 02/30] Train=1.3258 | Test=3.2610 | Acc=11.72%
# ★ New Best Accuracy: 11.72% (Round 2)
#
# Communication Round 3/30
# [Round 03/30] Train=1.2983 | Test=3.3723 | Acc=11.63%
#
# Communication Round 4/30
# [Round 04/30] Train=1.2655 | Test=4.7671 | Acc=13.36%
# ★ New Best Accuracy: 13.36% (Round 4)
#
# Communication Round 5/30
# [Round 05/30] Train=1.2332 | Test=3.5987 | Acc=13.82%
# ★ New Best Accuracy: 13.82% (Round 5)
#
# Communication Round 6/30
# [Round 06/30] Train=1.2251 | Test=12.1446 | Acc=15.13%
# ★ New Best Accuracy: 15.13% (Round 6)
#
# Communication Round 7/30
# [Round 07/30] Train=1.2010 | Test=3.9011 | Acc=20.67%
# ★ New Best Accuracy: 20.67% (Round 7)
#
# Communication Round 8/30
# [Round 08/30] Train=1.1896 | Test=4.9594 | Acc=18.04%
#
# Communication Round 9/30
# ...

# %%
from analysis import generate_all_analysis

# %%
generate_all_analysis()
# Out:
# ...
# GENERATING ANALYSIS
# ...
# Experiment Log Loaded
# ...
# Experiments : 7
#
# ...
# Checking Experiment Files
# ...
# ✓ FedAvg
# ✓ DP_Validation
# ✓ DP-0R
# ✓ DP-1
# ✓ DP-2
# ✓ DP-3
# ✓ DP-4
#
# Valid Experiments : 7
#
# Experiments used for dissertation:
#    • FedAvg
#    • DP-1
#    • DP-2
#    • DP-3
#    • DP-4
#
# ✓ Figure_4_1_AccuracyComparison.png
# ✓ Figure_4_2_TrainingLossComparison.png
# ✓ Figure_4_3_TestLossComparison.png
# ✓ Figure_4_4_BestAccuracyComparison.png
# ✓ Figure_4_5_PrivacyUtilityTradeoff.png
# ✓ Figure_4_6_TrainingTimeComparison.png
# ✓ Table_4_1_ExperimentalConfiguration.csv
# ✓ Table_4_2_ResultsSummary.csv
# ✓ Table_4_3_PrivacyUtilityTradeoff.csv
# ✓ Table_4_4_PerformanceMetrics.csv
# ✓ Table_4_5_ExperimentRanking.csv
# ✓ Table_4_6_ComparativePerformance.csv
# ✓ Table_4_7_Statistics.csv
# ✓ Analysis_Report.txt
# ...
# Analysis completed successfully.
# ...
